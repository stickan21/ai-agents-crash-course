# %% [markdown]
# # Short-Term Memory

# %%
import dotenv
from agents import Agent, Runner, SQLiteSession, trace

dotenv.load_dotenv()
# Out:
# True

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
)

# %% [markdown]
# ## No Memory

# %%
result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")
print(result.final_output)
# Out:
# 1) Bananas: 8/10 - Nutrient-dense with potassium, fiber, vitamins; natural sugars.
# 2) Lollipop: 2/10 - Mostly sugar and empty calories; no meaningful nutrients.

# %%
result = await Runner.run(nutrition_agent, "Add apples to the comparison")
print(result.final_output)
# Out:
# I’m missing the foods to compare. Do you want apples added to the current X and Y comparison (making it apples, X, and Y)? If so, please specify what X and Y are.
#
# In the meantime, here’s how I’ll format once you confirm:
# 1) [Most healthy] - Apple: 8/10
# 2) [Next] - X: 7/10
# 3) [Least] - Y: 5/10
#
# Please provide X and Y (or confirm you want apples added to X and Y).

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session = session
)
print(result.final_output)
# Out:
# 1) Bananas: 8/10 - Good fiber, potassium, vitamins; natural sugars but overall nutritious.
# 2) Lollipop: 2/10 - Mostly sugar, negligible nutrients.

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session = session
    )

print(result.final_output)
# Out:
# 1) Bananas: 8/10 - Good fiber, potassium, vitamins; natural sugars but balanced.
# 2) Apples: 7/10 - Fiber, vitamin C, polyphenols; moderate sugars.
# 3) Lollipop: 2/10 - Mostly sugar, negligible nutrients.
